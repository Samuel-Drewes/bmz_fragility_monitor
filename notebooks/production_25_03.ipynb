# %%
import pandas as pd
import numpy as np

# %%
full_df = pd.read_csv("../upload_data/full_df.csv")

full_df = full_df\
    .rename(columns={'name': 'Country Name', 'weighted_mean': "Total Score"})\
    .drop(columns = ['iso', 'country-code'])\
    .set_index('Country Name')\
    .dropna(thresh=4)

# %%
full_df
# Out:
#               Dimension_G  Dimension_S  Dimension_I  Dimension_C  Dimension_E  \
# Country Name
# Denmark          1.500000     0.937877     0.791002     1.316087     0.435523
# Norway           1.219741     0.945633     0.948538     1.341439     0.500000
# Luxembourg       1.197979     0.791160     0.948023     1.347068     0.362738
# Sweden           1.387357     0.777471     0.774226     1.300390     0.425640
# Switzerland      1.048410     0.714957     0.958655     1.351027     0.447780
# ...                   ...          ...          ...          ...          ...
# Myanmar         -1.189872     0.394712    -0.078129    -1.397936    -0.276679
# Libya           -1.049753    -0.316533          NaN    -0.636338    -0.166466
# Sudan           -0.861861    -0.840882    -0.282799    -0.670154    -0.377379
# Somalia         -1.148255    -1.000000          NaN    -0.396857    -0.358517
# South Sudan     -1.223234    -0.186487    -0.893408    -0.517689          NaN
#
#               Dimension_R  Total Score
# Country Name
# Denmark          0.220542     0.866839
# Norway           0.191078     0.857738
# Luxembourg       0.227067     0.812339
# Sweden           0.196767     0.810308
# Switzerland      0.209781     0.788435
# ...                   ...          ...
# Myanmar          0.148125    -0.399963
# Libya           -0.206130    -0.475044
# Sudan           -0.027945    -0.510170
# Somalia          0.107331    -0.559260
# South Sudan     -0.178028    -0.599769
#
# [163 rows x 7 columns]
